# %% [markdown]
# <a href="https://colab.research.google.com/github/ekaratnida/Applied-machine-learning/blob/master/Week05-Logistic/Stock_forecast.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.ultimatepython.co/post/python-yahoo-finance

# %%
# !pip install pandas
# !pip install numpy
# !pip install requests
# !pip install lxml
# !pip install yfinance

# %%
import yfinance as yf

# %%
mbk = yf.Ticker('mbk.bk')
interval = '1h'
start = '2023-9-1'
end = '2023-9-7'
mbk_price_df = mbk.history(interval=interval,start=start,end=end)
mbk_price_df
# Out:
#                                 Open       High        Low      Close  \
# Datetime
# 2023-09-01 10:00:00+07:00  18.700001  19.400000  18.700001  19.200001
# 2023-09-01 11:00:00+07:00  19.200001  19.400000  18.900000  19.000000
# 2023-09-01 12:00:00+07:00  19.000000  19.000000  18.900000  19.000000
# 2023-09-01 14:00:00+07:00  18.900000  19.000000  18.900000  19.000000
# 2023-09-01 15:00:00+07:00  19.000000  19.000000  18.799999  18.900000
# 2023-09-01 16:00:00+07:00  18.900000  19.000000  18.799999  18.900000
# 2023-09-04 10:00:00+07:00  19.100000  19.600000  19.100000  19.500000
# 2023-09-04 11:00:00+07:00  19.500000  19.600000  19.100000  19.299999
# 2023-09-04 12:00:00+07:00  19.299999  19.299999  19.100000  19.100000
# 2023-09-04 14:00:00+07:00  19.200001  19.200001  19.100000  19.200001
# 2023-09-04 15:00:00+07:00  19.100000  19.200001  19.100000  19.200001
# 2023-09-04 16:00:00+07:00  19.100000  19.299999  19.100000  19.200001
# ...
